# %% [markdown]
# # Tracing the Cold $H_2$ Gas in the Milky Way
# #### Statistics Project by Janek Rudolph, Leon Großmann and Kevin Weber

# %% [markdown]
# ## Literature Rewiev

# %% [markdown]
# ### Molecular Hydrogen Generally and its Importance in the Universe

# %% [markdown]
# Molecular hydrogen ($H_2$) is the simplest molecule, composed of two hydrogen atoms, and was the first neutral molecule formed in the universe. Additionally, it is the most common molecule in the universe and plays a key role in the formation of stars and galaxies.
#
# In the ISM (Interstellar Medium), molecular hydrogen is the primary component of cosmic molecular clouds. These clouds are large, dense regions and are among the coldest objects in the universe, with temperatures ranging from 10 to 50 Kelvin. In the coldest and densest corners of these clouds, star formation occurs. $H_2$ is a highly effective coolant at the low temperatures found in molecular clouds, which is essential as it allows the gas to compress further, eventually reaching densities that enable gravitational collapse and lead to star formation.

# %%
from IPython.display import Image
image1='galactic cloud.png'
Image(image1)

# %% [markdown]
# **Figure 1:** Star-forming region NGC 1333, located in the Perseus molecular cloud, approximately 960 light-years away. Picture by Hubble. (Source: https://spacenews.com/ngc-1333-the-star-forming-perseus-molecular-cloud-as-seen-by-hubble/)

# %% [markdown]
# ### Formation of Molecular Hydrogen
# Although $H_2$ is the most abundant molecule in space, its formation is complex and not easily maintained. The issue with molecular hydrogen is that it is vulnerable to high-energy ultraviolet (UV) radiation, especially at wavelengths around 912-1100 angstroms (~90-110 nm). When $H_2$ molecules absorb UV photons, they are excited to higher energy states. If enough energy is absorbed, the bond between the two hydrogen atoms breaks, releasing them back into atomic form in a process known as photodissociation. This vulnerability creates the need for some form of protection against UV radiation to maintain stable levels of $H_2$. Additionally, the formation of molecular hydrogen itself is inefficient in the ISM without dust particles acting as catalysts.

# %% [markdown]
# ##### Shielding of Molecular Hydrogen
# A natural shield is provided by higher densities found in cosmic clouds, where a density greater than 100 particles/cm³ is necessary to counterbalance the rate of photodissociation. Dust grains—tiny solid particles composed of elements such as carbon, silicon, and metals—are concentrated in dense regions like cosmic clouds and act as an effective shield for molecular hydrogen. These particles are highly efficient at absorbing and scattering UV radiation, thus surrounding molecular hydrogen and absorbing much of the harmful UV light before it reaches the $H_2$ molecules.
# But, $H_2$ can protect itself as well through a process called self-shielding, in which the outer layers of a molecular cloud absorb UV radiation and undergo dissociation, preserving the inner layers of $H_2$ from exposure.

# %% [markdown]
# ##### $H_2$ Formation on Dust Particles
# When a hydrogen atom collides with a dust grain and adheres to its surface, it can migrate across the surface to find another hydrogen atom. When two hydrogen atoms meet on the grain surface, they combine to form molecular hydrogen ($H_2$). This bonding process releases a small amount of energy, which is absorbed by the dust grain and dissipated as heat. The newly formed $H_2$ molecule then gains enough energy to escape from the dust particle.

# %% [markdown]
# ##### Gas-Phase Reactions
# In very low-density regions, where dust grain catalysis is inefficient, alternative gas-phase reactions can form $H_2$, this process though is far less efficient and much rarer in the ISM. In this process, a proton (hydrogen ion) — usually created by cosmic rays — combines with a hydrogen atom to form an $H_2⁺$ ion. This $H_2⁺$ ion then reacts with either a free electron in the ISM or another hydrogen atom, resulting in the formation of neutral molecular hydrogen and a hydrogen ion.
#
# Note: $H_2$ cannot generally form in the ISM through the direct collision of two hydrogen atoms. The reason behind this is that when two hydrogen atoms combine, energy is released as they transition from an excited state to a lower bound state. For the $H_2$ molecule to remain stable, this energy must be released or transferred; otherwise, the molecule will break apart again. In the ISM, there is virtually no means of dissipating this energy. When H₂ forms on a dust particle, the energy can be discharged into the grain, which makes dust essential for the formation of molecular hydrogen.

# %% [markdown]
# ### Distribution of Molecular Hydrogen in the Milky Way
# For understanding galactic evolution, molecular hydrogen is crucial. The amount and distribution of $H_2$ in a galaxy determine the galaxy's capacity to form new stars. Galaxies rich in $H_2$ are often actively forming stars, while galaxies with little $H_2$ tend to be older, less active, and often “quenched” in terms of star formation. Since the formation of $H_2$ occurs primarily in cosmic clouds, these clouds are naturally the main locations where molecular hydrogen can be found. Generally, molecular clouds are located in regions with increased density and mass. In a spiral galaxy like the Milky Way, this typically occurs in the spiral arms. The highest concentrations of $H_2$ are found in the inner regions of the galaxy, within about 5 kpc of the galactic center, where the disk is densest.
# Aligning with expectations, Figure 2 illustrates the distribution of molecular hydrogen in the Milky Way indirectly, using one of its most commonly used tracers, CO. In figure 2, we can clearly identify the galactic plane as a horizontal line, the spiral arms on either side (left and right corners), and the significantly increased density in the central region of the galaxy.

# %%
image2 = 'Killer Figure.png'
Image(image2)

# %% [markdown]
# **Figure 2:** This all-sky image shows the distribution of carbon monoxide (CO), a molecule used by astronomers to trace molecular clouds across the sky, as seen by Planck. (Source: https://www.nasa.gov/image-article/all-sky-image-of-molecular-gas-three-molecular-cloud-complexes-seen-by-planck/)

# %% [markdown]
# ### Why is it so Hard to Detect $H_2$?
# Due to many reasons, we would really like to know the exact distribution of molecular hydrogen clouds in our galaxy and others as well. Interestingly, in most cases, it is impossible for us to detect $H_2$ directly. The main issues are:
#
# 1. $H_2$ is a symmetrical molecule and lacks a permanent dipole moment, which prevents it from emitting or absorbing light in the radio and infrared wavelengths commonly used to observe other molecules.
#
# 2. Although $H_2$ can technically emit through quadrupole transitions (a higher-order effect), these transitions are extremely weak and occur only under specific conditions, such as high temperatures (over 100 K), where the molecule has enough energy to enter an excited state. But, these temperatures are not typically found in classical cosmic clouds.
#
# 3. $H_2$ can absorb UV light, and these absorptions can, in theory, be used to detect it. However, UV light is mostly absorbed by interstellar dust and gas, as explained earlier, making it difficult to observe $H_2$ directly in dense molecular clouds.

# %% [markdown]
# ### The History of the Hunt for $H_2$ ###
#
# #### Early Works and Ideas ####
#
# In 1904, Johannes Hartmann observed the spectral lines of ionized calcium (Ca II) that appeared to remain unchanged despite the star’s motion. This finding led him to conclude that there was something between the light source and Earth that absorbed photons at a specific wavelength. The paper he published marks the first scientific evidence of the existence of clouds in the ISM. Later works of the early 20th century suggested that these interstellar clouds also consist of molecular components. In the following decades, further publications provided viable evidence for this idea. During the 1950s, the 21 cm line in radio spectra caused by atomic hydrogen was discovered, leading astronomers to search for a similar tracer of molecular hydrogen. The abundance of $H_2$ clouds was theorized in a paper published in 1951, but this very paper also discussed the potential difficulty of finding molecular hydrogen due to its physical properties.
#
# #### Searching for Effective Tracers ####
#
# Almost two decades later, in the late ’60s, new publications aimed to encourage scientists to shift their research objectives in a different direction. The development of an indirect $H_2$ tracing method was necessary. In the following years, a concept for the process of $H_2$ formation on dust particles was proposed, further supporting the idea that, in interstellar space, hydrogen is also abundant in its molecular form. During the ’70s, many new ideas and discoveries emerged, starting with a 1970 paper on observations of line radiation attributed to CO in cold interstellar gas, which introduced the molecule as a viable $H_2$ tracing candidate. This idea was successfully reinforced by papers published in the following years as CO was established as the primary tracer for molecular hydrogen. A notable theoretical advancement from this time is the CO-to-$H_2$ conversion factor, commonly denoted as XCO. The classic review paper on the evolution of CO as a tracer was published in 1986, providing an interesting view of the historical development of carbon monoxide as a tracer. Over the years, these carbon-monoxide-centered methods contributed to the search for interstellar molecular clouds and were continuously improved and refined until the 2000s. A more recent paper from 2013 gives a comprehensive review of CO as a tracer of $H_2$, also discussing the limitations and dependencies of this method. These limitations, mostly occurring in CO “dark” regions, have prompted a search for CO-unrelated tracing techniques.
#
# #### Modern Methods and Alternatives to CO ####
#
# With newer and more advanced instrumentation, the accuracy and range of modern surveys have drastically increased each year. This has resulted in a wider spectrum of available $H_2$ tracing methods, as well as an improved understanding of the role CO holds in locating molecular hydrogen. This more recent data has been gathered using a myriad of instruments and techniques. While radio and (sub)millimeter surveys manage to map molecular tracers other than CO, which are particularly helpful in regions of low CO abundance, infrared observations can locate dust emissions, which are also suggested indicators of $H_2$ presence. Additionally, studies in the gamma-ray range allow for the detection of dark gas clouds interacting with cosmic rays. A paper published in the 2015 Annual Review of Astronomy and Astrophysics provides a broad discussion and analysis of the Milky Way’s molecular clouds and addresses the various methods of tracing $H_2$ and the effectiveness of these tracers.

# %% [markdown]
# ### Summary Tracer Methods

# %% [markdown]
# Using CO as a Proxy:
# Carbon monoxide (CO) is often used as a tracer for molecular hydrogen because it emits strongly in the radio wavelength. Particularly at the J=1→0J=1→0 rotational transition of 2.6 mm and thus is easy to detect.
# Since CO and $H_2$​ often coexist in dense molecular clouds,astronomers use the ratio between CO intensity and $H_2$​ column density, known as the CO-to-$H_2$​ conversion factor (or XCOXCO​), to estimate $H_2$ densities.
# The value of XCOXCO​ can vary with cloud conditions, such as metallicity,density and radiation environment.

# %% [markdown]
# UV Absorption Lines:
# In regions near hot stars, molecular hydrogen can be detected through ultraviolet absorption lines in the Lyman and Werner bands, which occur around 912–1100 Å.
# Observations from instruments like the Hubble Space Telescope and the Far Ultraviolet Spectroscopic Explorer (FUSE) have been crucial in directly detecting $H_2$​ via this method, especially in translucent and diffuse regions of the ISM. They found that the $H_2$ column density varies widely, reflecting differneces in olecular cloud density, UV radiation levels, and gas temperature across the ISM.

# %% [markdown]
# Infrared Emission Lines:
# Vibrational and rotational transitions of $H_2$ in the near-infrared, particularly at wavelengths of 2.12 µm, can be used to study warmer molecular hydrogen, such as in photodissociation regions (PDRs) near hot stars or shocked gas. $H_2$ infrared emission can provide insight into the conditions of the gas such as temperature distribution.
# Instruments like the Spitzer Space Telescope and ground-based observatories equipped with IR spectrometers have provided valuable data on $H_2$​ in these environments

# %% [markdown]
# Gamma-Ray Observations:
# Cosmic rays interacting with $H_2$​ in molecular clouds produce gamma-ray emissions that can be detected by telescopes like the Fermi Gamma-ray Space Telescope.
# This method, while indirect, allows estimation of molecular hydrogen in regions where CO is under-abundant, such as in low-metallicity environments where traditional methods may be less effective

# %% [markdown]
# $2 \times 10^{20} \,\text{cm}^{-2} (\text{K km s}^{-1})^{-1}$
#
# Here's a breakdown of what each part means:
#  $2 \times 10^{20} \,\text{cm}^{-2}$: This part represents a column density, which is a measure of the number of particles (e.g., hydrogen molecules) per square centimeter along a line of sight. The unit $\text{cm}^{-2}$ indicates the density per square centimeter.
#
#  $(\text{K km s}^{-1})^{-1}$: This unit corresponds to the "brightness temperature" scale, often observed in radio astronomy to measure line emissions. The combination of Kelvin (K), kilometers per second (km/s), and the reciprocal exponent means that this expression converts from a measurement of brightness temperature (in K km/s) to column density (in particles per cm $^{-2}$).
#
# In simpler terms, this factor  $2 \times 10^{20} \,\text{cm}^{-2} (\text{K km s}^{-1})^{-1}$  is often used to estimate the amount of molecular hydrogen present along a given line of sight based on observed emission from carbon monoxide (CO), which is an indirect tracer of hydrogen molecules.

# %% [markdown]
# Integration over velocity: By integrating this intensity over the velocity (in km/s), we obtain the area under the line, which gives 𝑊(N2H+). This area represents the total radiative power of the molecules along the line of sight across all velocities, but without a direct conversion into an energy unit.
#
# In summary:
# 𝑊(N2H+)
# W(N2H+) indicates the total "amount" of radiation emitted by N2H+ molecules along the line of sight, integrated over the velocities, in the unit K/km*s^-1.
# Thus, it is more a measure of the total emission of these molecules in the cloud, but not the energy per unit time.

# %% [markdown]
# ## First Data Analysis of Taurus Molecular Cloud Filament L1495

# %% [markdown]
# The given datasets contain, as can be seen below the 2D location data for extinction values and the column densities of two tracers for $H_2$. Additionally, the specific conversion factor is given and the estimated $H_2$ column densities with each tracer.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from astropy.io import ascii, fits

df = pd.read_csv(r'L1495_C18O_75_raw_processed_comb.dat', delimiter=r'\s+')
df.head(5)
# Out:
#           ra        dec   W(C18O)        AV    AV_sig  AV_n       N(C18O)  \
# 0  64.152252  27.715528 -0.098954  1.120753  1.523746  20.0 -9.810309e+13
# 1  64.152252  27.725944 -0.194590  1.032003  1.512752  19.0 -1.929165e+14
# 2  64.152252  27.736361 -0.220780  0.917129  1.498738  19.0 -2.188813e+14
# 3  64.152252  27.746778 -0.025434  0.934342  1.485701  19.0 -2.521547e+13
# 4  64.152252  27.757194 -0.205760  1.065620  1.485235  19.0 -2.039905e+14
#
#           N(H2)       X(C18O)       ra_2      dec_2  W(13CO)      AV_2  \
# 0  1.053508e+21 -9.312042e-08  64.154603  27.713444   2.0439  1.157326
# 1  9.700825e+20 -1.988661e-07  64.154603  27.730111   2.4861  0.972764
# 2  8.621017e+20 -2.538927e-07  64.154603  27.738444   2.9253  0.864260
# 3  8.782815e+20 -2.871000e-08  64.154603  27.746778   3.0815  0.858284
# 4  1.001683e+21 -2.036477e-07  64.154603  27.755111   2.9079  0.942692
#
#    AV_sig_2  AV_n_2       N(13CO)       N(H2)_2   X(13CO)
# ...

# %%
plt.figure(figsize=(9, 6))
sc_1 = plt.scatter(df["ra_2"], df["dec_2"], c=df["N(13CO)"], cmap='plasma', s=50, alpha=0.7)


plt.colorbar(sc_1, label="13CO column density")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("13CO Column Density")
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 3:** 13CO density distribution in Taurus molecular cloud filament L1495
#
# This figure gives a good first impression of what the cloud filament looks like. We plot the $^{13}CO$ column density because $^{13}CO$ forms more easily than $C^{18}O$.

# %%
plt.figure(figsize=(9, 6))
sc_2 = plt.scatter(df["ra_2"], df["dec_2"], c=df["N(H2)_2"], cmap='plasma', s=50, alpha=0.7)


plt.colorbar(sc_2, label="H2 column density")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("H2 Column Density Distribution via 13CO Tracer")
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 4:** Assumed $H_2$ distribution in Taurus molecular cloud filament L1495 using $^{13}CO$ as tracer.
#
# This figure provides a good estimate of where the $H_2$​ may be distributed in the cloud. Since it is derived from a conversion factor, we need to cross-match it with the plot of $H_2$​ using $C^{18}O$ for the conversion

# %%
plt.figure(figsize=(9, 6))
sc_3 = plt.scatter(df["ra"], df["dec"], c=df["N(C18O)"], cmap='plasma', s=50, alpha=0.7)


plt.colorbar(sc_3, label="C18O column density")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("C18O Column Density")
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 5:** $C^{18}O$ distribution in Taurus molecular cloud filament L1495
#
# This figure provides a good estimate of where the densest regions in the cloud filaments are located. Since $C^{18}O$ forms under higher pressure, we can assume that the regions where $C^{18}O$ is more abundant are the densest.

# %%
plt.figure(figsize=(9, 6))
sc_4 = plt.scatter(df["ra"], df["dec"], c=df["N(H2)"], cmap='plasma', s=50, alpha=0.7)


plt.colorbar(sc_4, label="H2 column density")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("H2 Column Density Distribution via C18O Tracer")
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 6:** Assumed $H_2$ distribution in Taurus molecular cloud filament L1495 using $C^{18}0$ as tracer.
#
# This figure shows the $H_2$ column density, plotted using the $C^{18}O$ conversion factor as an estimator. It can be seen that both plots using different conversion factors are similar.

# %%
filtered_df = df[(df['AV'] >= 0) & (df['N(C18O)'] >= 0)].dropna(subset=['AV', 'N(C18O)'])

pv_AV = filtered_df['AV']
pv_C18O = filtered_df['N(C18O)']

plt.figure(figsize=(8, 6))
plt.scatter(pv_C18O, pv_AV, color='b', alpha=0.1, label='N(C18O) vs. Av')
plt.xlabel("N(C18O)") 
plt.ylabel("Av")
plt.xlim(left=0)      
plt.ylim(bottom=0)   
plt.title("Relation between Av and N(C18O) in Cloud L1495")
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 7:** Relation between $Av$ and $N(C180)$ in the Taurus molecular cloud filament L1495.
#
# Here we can see, that there is a almost linear relationship between $Av$ and $N(C180)$ with a heteroscadastic tendency, as it seems.

# %%
b211 = pd.read_csv("B211.dat", sep=r"\s+")
b213 = pd.read_csv("B213.dat", sep=r"\s+")
b7 = pd.read_csv("B7.dat", sep=r"\s+")
b216 = pd.read_csv("B216.dat", sep=r"\s+")



plt.hist(b211['AV'], bins=50, alpha=0.35, label='Av of B211', color='blue')
plt.hist(b7['AV'], bins=50, alpha=0.35, label='Av of B7', color='brown')
plt.hist(b213['AV'], bins=50, alpha=0.35, label='Av of B213', color='green')
plt.hist(b216['AV'], bins=50, alpha=0.35, label='Av of B216', color='black')

plt.xlabel('AV')
plt.ylabel('Häufigkeit')
plt.title('AV Distribution of Cloud Fragments')
plt.legend()

plt.show()

# %% [markdown]
# **Figure 8:** Distrubution of $Av$ in different parts of the molecular cloud.
#
# In this figure, we plot the extinction of different parts of the cloud against each other to identify the densest regions and determine whether the cloud is uniform. This is the case for B216, B213, and B211, while the higher extinction in B7 suggests a denser region.

# %%
plt.hist(b211['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B211', color='blue')
plt.hist(b7['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B7', color='brown')
plt.hist(b213['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B213', color='green')
plt.hist(b216['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B216', color='black')

plt.xlabel('H2')
plt.ylabel('Frequency')
plt.title('H2 Column Density Distribution of Cloud Fragments')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.hist(b211['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B211', color='blue')
#       2 plt.hist(b7['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B7', color='brown')
#       3 plt.hist(b213['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B213', color='green')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Figure 9:** Distrubution of $H2$ in different parts of the molecular cloud.
#
# Here, we plot all the different parts of the cloud against each other to examine whether the extinction correlates with the $H_2$ distribution. As seen, the $H_2$ distribution closely matches the extinction.
#
# We can also identify, that the distribution of the Av values, as well as of the $H_2$ column density, looks really similar in all parts of the cloud.

# %% [markdown]
# ## Confidence Intervals

# %% [markdown]
# For this exercise, we chose to plot the X-factor for both CO isotopologues $\text{C}^{18}\text{O}$ and $^{13}\text{CO}$ as it is a combined quantity already provided in the raw data. Interestingly, the distributions of the two conversion factors differ fundamentally in shape, which led us to fit different types of models to their respective histograms. To improve the analysis, we applied a constraint to both datasets, including only values greater than zero and excluding extreme outliers. This adjustment, however, affected the compatibility with the fitted plots — particularly for the $X(\text{C}^{18}\text{O})$-factor. To address this, we included an additional figure showing the $X(\text{C}^{18}\text{O})$ data with negative values retained for comparison.
#
# After computing the first two moments for the two datasets, we determined the 2.5-sigma confidence interval for the mean, which is given by:
#
# $
# \left( \bar{X} - Z_{\alpha/2} \cdot \frac{\sigma}{\sqrt{n}},  \bar{X} + Z_{\alpha/2} \cdot \frac{\sigma}{\sqrt{n}} \right)
# $
#
# This interval covers nearly 99% of the possible values for the true mean.

# %%
from scipy.stats import norm

# plot
plt.figure(figsize=(12, 7))

# data filtering
pv_XC18O = (df['X(C18O)'] >= 0) & (df['X(C18O)'] <= 0.8e-6)  
data_C18O = df['X(C18O)'][pv_XC18O] 

# Histogramm
plt.hist(data_C18O, bins=100, density=True, color='skyblue', edgecolor='skyblue', alpha=0.8, label='Histogram')

# Gaussian distribution
mean_C18O = np.mean(data_C18O)  # mean
std_C18O = np.std(data_C18O)    # standard deviation
data_C18O_tn = data_C18O.count()
std_error_C18O = std_C18O/(data_C18O_tn**(0.5))
x_C18O = np.linspace(min(data_C18O), max(data_C18O), 1000)  # x-values for PDF
pdf_C18O = norm.pdf(x_C18O, mean_C18O, std_C18O)  # PDF of the normal distribution

# Confidence interval
count_C18O = df['X(C18O)'].count()
lost_data_frc = data_C18O_tn/count_C18O
CI_C18O_l = mean_C18O - 2.5*std_error_C18O
CI_C18O_u = mean_C18O + 2.5*std_error_C18O
plt.axvline(CI_C18O_l, color='purple', linestyle='-', lw=2, label=f'lower bound of CI for the mean = {CI_C18O_l:.2e}')
plt.axvline(CI_C18O_u, color='purple', linestyle='-', lw=2, label=f'upper bound of CI for the mean = {CI_C18O_u:.2e}')

# Plot of guassian distibution
plt.plot(x_C18O, pdf_C18O, color='red', lw=2, label='Gaussian Fit')

# mean and standard deviation lines
plt.axvline(mean_C18O, color='blue', linestyle='--', lw=2, label=f'Mean = {mean_C18O:.2e}')
plt.axvline(mean_C18O + std_C18O, color='darkgreen', linestyle='--', lw=2, label=f'+1σ = {mean_C18O + std_C18O:.2e}')
plt.axvline(mean_C18O - std_C18O, color='darkgreen', linestyle='--', lw=2, label=f'-1σ = {mean_C18O - std_C18O:.2e}')
plt.axvline(mean_C18O + 2.5*std_C18O, color='lime', linestyle='--', lw=2, label=f'+2.5σ = {mean_C18O+ 2.5*std_C18O:.2e}')

# axes and plot titel
plt.title('Distribution of X(C18O) with Gaussian Fit', fontsize=16)
plt.xlabel('X(C18O)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xlim(min(data_C18O), 0.8e-6)

# legend
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=12)

# Layout 
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 9:** Our Gaussian fit for this dataset ($X(\text{C}^{18}\text{O})$-factor) appears slightly shifted due to the fact that we altered the range of the datapoints to be distributed within a physically realistic domain, i.e. stricly greater than zero, as densities do not take on negative values.

# %%
count_C18O = df['X(C18O)'].count()
lost_data_frc = data_C18O_tn/count_C18O
print(f"By cutting negative values and outliers we get rid of a fraction of {100*lost_data_frc:.2f}% of the original dataset.")
C18O_CI_l = mean_C18O - 2.5*std_error_C18O
C18O_CI_u = mean_C18O + 2.5*std_error_C18O
print(f"The confidence interval for the mean, for a 2.5σ range, lies between {C18O_CI_l:.2e} and {C18O_CI_u:.2e}.")
# Out:
# By cutting negative values and outliers we get rid of a fraction of 92.76% of the original dataset.
# The confidence interval for the mean, for a 2.5σ range, lies between 1.74e-07 and 1.78e-07.

# %%
from scipy.stats import norm, laplace, logistic
import matplotlib.pyplot as plt


# plot
plt.figure(figsize=(12, 7))
 
pv_XC18O = (df['X(C18O)'] >= -2e-7) & (df['X(C18O)'] <= 6e-7)  
data_C18O = df['X(C18O)'][pv_XC18O] 

# Histogramm
plt.hist(data_C18O, bins=100, density=True, color='skyblue', edgecolor='skyblue', alpha=0.8, label='Histogram')

# Gaussian distribution
mean_C18O = np.mean(data_C18O)  # mean
std_C18O = np.std(data_C18O)    # standard deviation
data_C18O_tn = data_C18O.count()
std_error_C18O = std_C18O/(data_C18O_tn**(0.5))
x_C18O = np.linspace(min(data_C18O), max(data_C18O), 1000)  # x-values for PDF
pdf_C18O = norm.pdf(x_C18O, mean_C18O, std_C18O)  # PDF of the normal distribution

# Plot of guassian distibution
plt.plot(x_C18O, pdf_C18O, color='red', lw=2, label='Gaussian Fit')
from scipy.stats import norm, laplace, logistic
import matplotlib.pyplot as plt
import numpy as np

# Laplace Distribution Fit
pdf_laplace = laplace.pdf(x_C18O, loc=mean_C18O, scale=std_C18O / np.sqrt(2))
plt.plot(x_C18O, pdf_laplace, label='Laplace Fit', color='orange', linestyle='--')

# Logistic Distribution Fit
pdf_logistic = logistic.pdf(x_C18O, loc=mean_C18O, scale=std_C18O / np.sqrt(3))
plt.plot(x_C18O, pdf_logistic, label='Logistic Fit', color='green', linestyle='-.')

# Confidence interval
count_C18O = df['X(C18O)'].count()
lost_data_frc = data_C18O_tn/count_C18O
CI_C18O_l = mean_C18O - 2.5*std_error_C18O
CI_C18O_u = mean_C18O + 2.5*std_error_C18O
plt.axvline(CI_C18O_l, color='purple', linestyle='-', lw=2, label=f'lower bound of CI for the mean = {CI_C18O_l:.2e}')
plt.axvline(CI_C18O_u, color='purple', linestyle='-', lw=2, label=f'upper bound of CI for the mean = {CI_C18O_u:.2e}')

# mean and standard deviation lines
plt.axvline(mean_C18O, color='blue', linestyle='--', lw=2, label=f'Mean = {mean_C18O:.2e}')
plt.axvline(mean_C18O + std_C18O, color='darkgreen', linestyle='--', lw=2, label=f'+1σ = {mean_C18O + std_C18O:.2e}')
plt.axvline(mean_C18O - std_C18O, color='darkgreen', linestyle='--', lw=2, label=f'-1σ = {mean_C18O - std_C18O:.2e}')
plt.axvline(mean_C18O + 2.5*std_C18O, color='lime', linestyle='--', lw=2, label=f'+2.5σ = {mean_C18O+ 2.5*std_C18O:.2e}')
plt.axvline(mean_C18O - 2.5*std_C18O, color='lime', linestyle='--', lw=2, label=f'-2.5σ = {mean_C18O- 2.5*std_C18O:.2e}')

# axes and plot titel
plt.title('Distribution of X(C18O) with Gaussian, Laplace and Logistic Fit', fontsize=16)
plt.xlabel('X(C18O)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xlim(min(data_C18O), 0.8e-6)

# legend
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=12)

# Layout 
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 10:** Here, in contrast to the previous $X(\text{C}^{18}\text{O})$ dataset, that only includes positive values, this dataset shows an altered range to represent the raw, though physically unrealistic, data more accurately. The first attempt of producing a global fit, in the plot shown as the red Gaussian Bell Curve, didn’t quite seem to represent the distribution of our data correctly. This could, of course, be attributed to the choice of our outlier range, that has direct influence on the data's standard deviation and confidence intervals. In order to adress this misrepresentation of our data, we tried comparing the histogram to other fits, namely the Laplace and Logistic distributions.

# %%
count_C18O = df['X(C18O)'].count()
lost_data_frc = data_C18O_tn/count_C18O
print(f"By cutting negative values and outliers we get to a fraction of {100*lost_data_frc:.2f}% of the original dataset.")
C18O_CI_l = mean_C18O - 2.5*std_error_C18O
C18O_CI_u = mean_C18O + 2.5*std_error_C18O
print(f"The confidence interval for the mean, for a 2.5σ range, lies between {C18O_CI_l:.2e} and {C18O_CI_u:.2e}.")
# Out:
# By cutting negative values and outliers we get to a fraction of 97.75% of the original dataset.
# The confidence interval for the mean, for a 2.5σ range, lies between 1.59e-07 and 1.64e-07.

# %%
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Plot
plt.figure(figsize=(12, 7))

# data filtering
pv_X13CO = (df['X(13CO)'] >= 0) & (df['X(13CO)'] <= 0.5e-5)  # Boolesche Maske erstellen
data_13CO = df['X(13CO)'][pv_X13CO]  # Gefilterte Daten

# Histogramm
plt.hist(data_13CO, bins=100, density=True, color='skyblue', edgecolor='skyblue', alpha=0.8, label='Histogram')

mean_13CO = np.mean(data_13CO)  # mean
std_13CO = np.std(data_13CO)    # standard deviation
data_13CO_tn = data_13CO.count()
std_error_13CO = std_13CO/(data_13CO_tn**(0.5))

# Fit Lognormal Distribution
shape, loc, scale = lognorm.fit(data_13CO, floc=0)  # Fit lognormal (forcing location to 0)
x_13CO = np.linspace(min(data_13CO), max(data_13CO), 1000)
pdf_13CO = lognorm.pdf(x_13CO, shape, loc, scale)  # Lognormal PDF
plt.plot(x_13CO, pdf_13CO, color='red', lw=2, label='Lognormal Fit')

# Confidence interval
count_13CO = df['X(13CO)'].count()
lost_data_13CO = data_13CO_tn/count_C18O
CI_13CO_l = mean_13CO - 2.5*std_error_13CO
CI_13CO_u = mean_13CO + 2.5*std_error_13CO
plt.axvline(CI_13CO_l, color='purple', linestyle='-', lw=2, label=f'lower bound of CI for the mean = {CI_13CO_l:.2e}')
plt.axvline(CI_13CO_u, color='purple', linestyle='-', lw=2, label=f'upper bound of CI for the mean = {CI_13CO_u:.2e}')

# mean and standard deviation lines
plt.axvline(mean_13CO, color='blue', linestyle='--', lw=2, label=f'Mean = {mean_13CO:.2e}')
plt.axvline(mean_13CO + std_13CO, color='darkgreen', linestyle='--', lw=2, label=f'+1σ = {mean_13CO + std_13CO:.2e}')
plt.axvline(mean_13CO - std_13CO, color='darkgreen', linestyle='--', lw=2, label=f'-1σ = {mean_13CO - std_13CO:.2e}')
plt.axvline(mean_13CO + 2.5*std_13CO, color='lime', linestyle='--', lw=2, label=f'+2.5σ = {mean_13CO + 2.5*std_13CO:.2e}')

# axes and plot titel
plt.title('Distribution of X(13CO) with lognormal Fit', fontsize=16)
plt.xlabel('X(13CO)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xlim(min(data_13CO),)

# Legend
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=12)

# Layout
plt.tight_layout()
plt.show()

# %% [markdown]
# **Figure 11:** Although this lognormal fit for the data doesn't seem to make a perfect match, it's significantly more representative of the data than a normal Gaussian bell curve.

# %%
count_13CO = df['X(13CO)'].count()
lost_data_13CO = data_13CO_tn/count_C18O
print(f"By cutting negative values and outliers we get to a fraction of {100*lost_data_13CO:.2f}% of the original dataset.")
CI_13CO_l = mean_C18O - 2.5*std_error_13CO
CI_13CO_u = mean_C18O + 2.5*std_error_13CO
print(f"The confidence interval for the mean, for a 2.5σ range, lies between {CI_13CO_l:.2e} and {CI_13CO_u:.2e}.")
# Out:
# By cutting negative values and outliers we get to a fraction of 99.17% of the original dataset.
# The confidence interval for the mean, for a 2.5σ range, lies between 1.48e-07 and 1.75e-07.

# %% [markdown]
# ## Hypothesis Testing
#
# When examining the molecular cloud, we may assume that $H_2$ is almost evenly distributed among the individual cloud fragments. To investigate this, we focus on two fragments that appear to differ the most: cloud fragments B7 and B211 (see the figure below, $H_2$ Density Distribution of Cloud Fragments, for reference). Cloud fragment B7, in particular, stands out due to its seemingly higher overall $H_2$ column density. This leads us to our hypothesis, which we aim to disprove at a 2-sigma significance level.
#
# $H_0$ : The mean column density of $H_2$ of the cloud fragments b211 and b7 are the same.
#
# $H_a$ : The mean column density of $H_2$ of the cloud fragments b7 is higher.
#
# Significance level: $2 \sigma$

# %%
plt.hist(b211['N(H2)'], bins=50, alpha=0.35, label='Distribution of B211', color='blue')
plt.hist(b7['N(H2)'], bins=50, alpha=0.35, label='Distribution of B7', color='brown')
plt.hist(b213['N(H2)'], bins=50, alpha=0.35, label='Distribution of B213', color='green')
plt.hist(b216['N(H2)'], bins=50, alpha=0.35, label='Distribution of B216', color='black')

plt.xlabel('H2 column density')
plt.ylabel('Frequency')
plt.title('H2 Column Density Distribution of Cloud fragments')
plt.legend()

plt.show()

# %% [markdown]
# **Figure 12:** $H_2$ column density distribution of cloud fragments B211, B7, B213 and B216

# %% [markdown]
# For a better understanding of which parts of the cloud we are looking at, there is a visualisation of the cloud fragments down below.

# %%
plt.figure(figsize=(9, 6))
sc = plt.scatter(b7["ra"], b7["dec"], c=b7["N(H2)"], cmap='plasma', s=50, alpha=0.7)

plt.colorbar(sc, label="Colum density")
plt.xlabel("Right ascension (RA)")
plt.ylabel("Deklination (Dec)")
plt.title("Column Density of H2 in Cloud Fraqment B7")
plt.grid(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.figure(figsize=(9, 6))
#       2 sc = plt.scatter(b7["ra"], b7["dec"], c=b7["N(H2)"], cmap='plasma', s=50, alpha=0.7)
#       4 plt.colorbar(sc, label="Colum density")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Figure 13:** column density of $H_2$ in cloud fraqment B7

# %%
plt.figure(figsize=(9, 6))
sc = plt.scatter(b211["ra"], b211["dec"], c=b211["N(H2)"], cmap='plasma', s=50, alpha=0.7)

plt.colorbar(sc, label="Colum Density")
plt.xlabel("Right ascension (RA)")
plt.ylabel("Deklination (Dec")
plt.title("Column Density of H2 in Cloud Fraqment B211")
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 14:** Column density of $H_2$ in cloud fraqment B211

# %% [markdown]
# Here we calculate and define all the values we need for the test we want to execute.

# %%
b7_mean = np.mean(b7['N(H2)'])
b211_mean = np.mean(b211['N(H2)'])
b7_std = np.std(b7['N(H2)'])
b211_std = np.std(b211['N(H2)'])
n1 = b7['N(H2)'].count()
n2 = b211['N(H2)'].count()

print(f"Mean of cloud fraqmant b7: {b7_mean:.2e}")
print(f"Mean of cloud fraqmant b211: {b211_mean:.2e}")
print(f"Standard deviation of cloud fraqment b7: {b7_std:.2e}")
print(f"Standard deviation of cloud fraqment b211: {b211_std:.2e}")
print(f"Sample size of cloud fraqment b7: {n1}")
print(f"Sample size of cloud fraqment b211: {n2}")
# Out:
# Mean of cloud fraqmant b7: 6.13e+21
# Mean of cloud fraqmant b211: 3.62e+21
# Standard deviation of cloud fraqment b7: 3.71e+21
# Standard deviation of cloud fraqment b211: 3.01e+21
# Sample size of cloud fraqment b7: 2490
# Sample size of cloud fraqment b211: 2370

# %%
plt.hist(b211['N(H2)'], bins=50, alpha=0.35, label='Distribution of B211', color='blue')
plt.hist(b7['N(H2)'], bins=50, alpha=0.35, label='Distribution of B7', color='red')


plt.xlabel('H2 column density')
plt.ylabel('Frequency')
plt.title('H2 Column Density Distribution of Cloud fragments B211 and B7')

plt.axvline(b7_mean, color='red', linestyle='-', lw=2, label=f'Mean of b7 = {b7_mean:.2e}')
plt.axvline(b211_mean, color='blue', linestyle='-', lw=2, label=f'Mean of b211= {b211_mean:.2e}')

plt.legend()
plt.show()

# %% [markdown]
# **Figure 15:** Histogram showing of the $H_2$ column density distribution of cloud fragments B211 and B7 and their means.

# %% [markdown]
# This histogram of the $H_2$ column density distribution for the two cloud fragments, along with their means, suggests a significant difference between them. To formally test this, we use a two-sample t-test with unknown population standard deviations but large sample sizes:

# %% [markdown]
# $$T_0 = \frac{\bar{X}-\bar{Y}}{\sqrt{S_1^{2}/n_1 + S_2^{2}/n_2}}$$

# %%
T_0 = (b7_mean-b211_mean)/((((b7_std**2)/n1) + ((b211_std**2)/n2))**(1/2))
print(f"T-value: {T_0:.2f}")
# Out:
# T-value: 25.96

# %% [markdown]
# Z-value for  $2\sigma \approx 2.03$
#
# Because $T_0=25.96>2.03$, $H_0$ can be rejected on a $2\sigma$-significance level and even lot higher then 99.9%.

# %%
p_value =   (1 - norm.cdf(abs(T_0)))

print(f"P-value for the executed test statistic: {p_value:.5g}")
# Out:
# P-value for the executed test statistic: 0

# %% [markdown]
# As indicated by the calculated p-value, there is essentially a 0% probability of observing our current test statistic under the assumption that the null hypothesis is true. Consequently, we reject $H_0$.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# The $H_2$ column density can be estimated using $C^{18}O$ as a tracer, with a certain conversion factor. This implies an approximately linear relationship, eliminating the need for data transformation. Consequently, we expect higher H₂ densities in regions with higher $C^{18}O$ densities, and similarly, lower values where $C^{18}O$ densities are lower.

# %%
filtered_df = df[(df['N(H2)'] >= 0) & (df['N(C18O)'] >= 0)].dropna(subset=['N(H2)', 'N(C18O)']) # negative values filtered out

pv_AV = filtered_df['N(H2)']
pv_C18O = filtered_df['N(C18O)']

plt.figure(figsize=(8, 6))
plt.scatter(pv_C18O, pv_AV, color='b', alpha=0.1, label='N(C18O) vs. N(H2)')
plt.xlabel("N(C18O)") 
plt.ylabel("N(H2)")
plt.xlim(left=0)      
plt.ylim(bottom=0)   
plt.title("Relation between N(H2) and N(C18O) in Cloud L1495")
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 16:** Relation between N(H2) and N(C18O) in cloud L1495.

# %% [markdown]
# From the plot above, we can infer that the data exhibits a heteroscedastic tendency, meaning the variance is not uniform. Which means, there is greater variance at higher $C^{18}O$ column densities, with measured values becoming less centered as density increases.

# %%
array_H2 = np.array([filtered_df['N(H2)']]) 
array_CO = np.array([filtered_df['N(C18O)']])  
mean_H2_CO = np.mean(array_H2 *array_CO)
mean_H2 = np.mean(array_H2)
mean_CO = np.mean(array_CO)
mean_CO_2 = np.mean(array_CO**2)
n_H2_CO = filtered_df['N(H2)'].count()

B_1 = (mean_H2_CO - (mean_H2*mean_CO))/(mean_CO_2 - mean_CO**2)
B_0 = mean_H2 - B_1*mean_CO

X_values = np.linspace(0, 4.4*10**15, num=10**3) 
Y_values = filtered_df['Y_values'] = B_0 + B_1*filtered_df['N(C18O)']

lin_reg_line = B_0 + B_1*X_values

# %%
plt.figure(figsize=(8, 6))
filtered_df = df[(df['N(H2)'] >= 0) & (df['N(C18O)'] >= 0)].dropna(subset=['N(H2)', 'N(C18O)'])

pv_H2 = filtered_df['N(H2)']
pv_C18O = filtered_df['N(C18O)']

plt.scatter(pv_C18O, pv_H2, color='b', alpha=0.1, label='N(C18O) vs. N(H2)')
plt.plot(X_values, lin_reg_line, color='r', label='linear relation')
plt.xlabel("N(C18O)") 
plt.ylabel("N(H2)")
plt.xlim(left=0, right=4.4*10**15)      
plt.ylim(bottom=0)   
plt.title("Relation between N(H2) and N(C18O) in Cloud L1495")
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 17:** Linear regression fit for the relationship between N(H2) and N(C18O) in cloud L1495.

# %%
var_mean_H2 = (((filtered_df['N(H2)'] - mean_H2)**2).sum()) / n_H2_CO
var_fit = (((filtered_df['N(H2)'] - Y_values)**2).sum()) / n_H2_CO
print(f"Value of the slope: {B_1:.2e}")
print(f"Value of the y-axes cross: {B_0:.2e}")
# Out:
# Value of the slope: 3.66e+06
# Value of the y-axes cross: 1.31e+21

# %% [markdown]
# When fitting a linear regression, we observe that: 1. for lower $C^{18}O$ column density values, the regression provides reasonably accurate predictions, and 2. the residuals do not exhibit significant heteroscedasticity, although a slight tendency remains. This trend is also visible in the plot below.

# %%
res = df['res'] = (pv_H2 - Y_values)**2

res_mean = res.mean()
B_1_2 = (res_mean - (res_mean*mean_CO))/(mean_CO_2 - mean_CO**2)
B_0_2 = res_mean - B_1_2*mean_CO

lin_reg_line_2 = B_0_2 + B_1_2*X_values

plt.figure(figsize=(8, 6))
plt.scatter(pv_C18O, res, color='b', alpha=0.1, label='N(C18O) vs. N(H2)')
plt.plot(X_values, lin_reg_line_2, color='r', label='linear relation')
plt.xlabel("N(C18O)") 
plt.ylabel("Residuals")
plt.xlim(left=0, right=4.4*10**15)      
plt.ylim(bottom=0)   
plt.title("Relation between the residuals of linear regression and N(C18O)")
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# **Figure 18:** Linear regression fit for the residuals of the linear regression line of fig. 17 and N(C18O).

# %% [markdown]
# When fitting a linear relationship to the residuals, we surprisingly observe even a slight negative correlation between the residuals and $C^{18}O$ column density. This results from the significantly higher number of observations in the lower density range. However, this suggests that using a heteroscedastic approach for a better linear regression fit may not be necessary.
#
# Additionally, the Pearson correlation coefficient indicates that the calculated fit is reasonably good, as shown below.

# %%
# Cov(X,Y)
Cov_CO_H2 = (1/(n_H2_CO - 1))*(((filtered_df['N(C18O)'] - mean_CO)*(filtered_df['N(H2)'] - mean_H2)).sum())
# Corelation coefficient
var_H2 = (1/(n_H2_CO - 1))*(((filtered_df['N(H2)'] - mean_H2)**2).sum())
var_CO = (1/(n_H2_CO - 1))*(((filtered_df['N(C18O)'] - mean_CO)**2).sum())          
r_CO_H2 = Cov_CO_H2/((var_CO**(1/2))*(var_H2**(1/2)))
print(f"The covariance of N(H2) and N(C18O) is: {Cov_CO_H2:.2e}")
print(f"Corelation coefficient: {r_CO_H2:.2f}")
# Out:
# The covariance of N(H2) and N(C18O) is: 1.64e+36
# Corelation coefficient: 0.84

# %% [markdown]
# Bootstrapping allows us to assess how likely the calculated slope of the linear regression is to accurately estimate the true slope of the underlying linear relationship.

# %%
from sklearn.linear_model import LinearRegression

# Parameter
N = n_H2_CO
K = 1000   
alpha = 0.032  

# Bootstrap-Process
bootstrap_estimates = []
for _ in range(K):
    # random sampling with replacement
    indices = np.random.choice(N, size=N, replace=True)
    X_sample = filtered_df['N(C18O)'].iloc[indices].values.reshape(-1, 1)
    y_sample = filtered_df['N(H2)'].iloc[indices].values

    # model adaptation
    model = LinearRegression()
    model.fit(X_sample, y_sample)
    bootstrap_estimates.append(model.coef_[0])  # saving of estimated slope value

# CI calculation
bootstrap_estimates = np.sort(bootstrap_estimates)
lower_bound = np.percentile(bootstrap_estimates, 100 * (alpha / 2))
upper_bound = np.percentile(bootstrap_estimates, 100 * (1 - alpha / 2))

print(f"The one sigma confidence interval for the value of the slope: [{lower_bound:.2e}, {upper_bound:.2e}]")
# Out:
# The one sigma confidence interval for the value of the slope: [3.58e+06, 3.74e+06]

# %% [markdown]
# The slope of the linear relationship for the original dataset is 3.66e+06. Since this value lies perfectly in the middle of the confidence interval, it appears to be a reliable estimator, suggesting that the original dataset is a good representative sample—likely due to its relatively large size.

# %% [markdown]
# ### References

# %% [markdown]
# Hartmann, J. (1904). "Investigations on the Spectrum and Orbit of δ Orionis." Astrophysical Journal, 19, 268–286.
#
# McKellar, A. (1940). "Evidence for the Molecular Origin of Some Hitherto Unidentified Interstellar Lines." Publications of the Dominion Astrophysical Observatory, 7, 251–272.
#
# Ewen, H. I., & Purcell, E. M. (1951). "Observation of a Line in the Galactic Radio Spectrum: Radiation from Galactic Hydrogen at 1,420 Mc./sec." Nature, 168, 356–357.
#
# Spitzer, L., & Greenstein, J. L. (1951). "The Luminosity Function and Stellar Evolution." Astrophysical Journal, 114, 407–418.
#
# Wilson, R. W., Jefferts, K. B., & Penzias, A. A. (1970). "Carbon Monoxide in the Orion Nebula." Astrophysical Journal, 161, L43–L45.
#
# Dickman, R. L., Snell, R. L., & Schloerb, F. P. (1986). "Carbon Monoxide as an Extraterrestrial Tracer." Annual Review of Astronomy and Astrophysics, 24, 479–525.
#
# Dame, T. M., Hartmann, D., & Thaddeus, P. (2001). "The Milky Way in Molecular Clouds: A New Complete CO Survey." Astrophysical Journal, 547, 792–813.
#
# Grenier, I. A., Casandjian, J. M., & Terrier, R. (2005). "Unveiling Extensive Clouds of Dark Gas in the Galactic Disk." Science, 307, 1292–1295.
#
# Bolatto, A. D., Wolfire, M., & Leroy, A. K. (2013). "The CO-to-H₂ Conversion Factor." Annual Review of Astronomy and Astrophysics, 51, 207–268.
#
# Heyer, M., & Dame, T. M. (2015). "Molecular Clouds in the Milky Way." Annual Review of Astronomy and Astrophysics, 53, 583–629.
