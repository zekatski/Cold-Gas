# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from astropy.io import ascii, fits

b211 = pd.read_csv("B211.dat", sep=r"\s+")
b211.head(2000)
# Out:
#              ra        dec   W(C18O)        AV    AV_sig  AV_n       N(C18O)  \
# 0     64.152255  27.715530 -0.098954  1.120759  3.680153  20.0 -9.810309e+13
# 1     64.152255  27.725947 -0.194590  1.031999  3.586607  19.0 -1.929165e+14
# 2     64.152255  27.736363 -0.220780  0.917114  3.472197  19.0 -2.188813e+14
# 3     64.152255  27.746780 -0.025434  0.934329  3.700409  19.0 -2.521547e+13
# 4     64.152255  27.757197 -0.205760  1.065630  3.815721  19.0 -2.039905e+14
# ...         ...        ...       ...       ...       ...   ...           ...
# 1995  64.751842  27.028030  0.284490  1.350630  7.340547  15.0  2.820434e+14
# 1996  64.751842  27.038447  0.303450  1.298981  9.043355  15.0  3.008403e+14
# 1997  64.751842  27.048863  0.224550  1.350126  8.852381  19.0  2.226189e+14
# 1998  64.751842  27.059280  0.089452  1.360997  6.815603  20.0  8.868301e+13
# 1999  64.751842  27.069697  0.179530  1.415108  4.396478  20.0  1.779860e+14
#
# ...

# %%
b213 = pd.read_csv("B213.dat", sep=r"\s+")
b213.head()
# Out:
#           ra        dec  W(C18O)         AV    AV_sig  AV_n       N(C18O)  \
# 0  64.845894  27.246780   2.7491  15.898384  2.013690   4.0  2.725458e+15
# 1  64.845894  27.257197   2.4211  13.227441  1.920061   8.0  2.400279e+15
# 2  64.845894  27.267613   2.1027  11.765449  1.797277   8.0  2.084617e+15
# 3  64.845894  27.278030   1.9450  10.367890  1.747480   9.0  1.928273e+15
# 4  64.845894  27.288447   1.8486   9.290133  1.712566  11.0  1.832702e+15
#
#           N(H2)       X(C18O)  W(13CO)       AV_2  AV_sig_2  AV_n_2  \
# 0  1.494448e+22  1.823722e-07  10.8710  14.464935  2.022074     2.0
# 1  1.243379e+22  1.930447e-07   9.9944  13.309977  1.832869     4.0
# 2  1.105952e+22  1.884907e-07   8.5372  11.040933  1.617959     8.0
# 3  9.745817e+21  1.978565e-07   8.4463  10.041244  1.549548     9.0
# 4  8.732725e+21  2.098660e-07   8.3034   9.358737  1.527354    11.0
#
#         N(13CO)       N(H2)_2       X(13CO)
# 0  1.077751e+16  1.359704e+22  7.926365e-07
# ...

# %%
b7 = pd.read_csv("B7.dat", sep=r"\s+")
b7.head()
# Out:
#           ra        dec  W(C18O)        AV    AV_sig  AV_n       N(C18O)  \
# 0  64.152255  28.132197  0.58059  3.834806  1.808870  19.0  5.755969e+14
# 1  64.152255  28.142613  0.73629  3.897593  1.751236  19.0  7.299579e+14
# 2  64.152255  28.153030  0.83407  3.895491  1.698073  19.0  8.268970e+14
# 3  64.152255  28.163447  0.61965  3.816413  1.705892  21.0  6.143210e+14
# 4  64.152255  28.173863  0.56520  3.732392  1.745705  19.0  5.603393e+14
#
#           N(H2)       X(C18O)  W(13CO)      AV_2  AV_sig_2  AV_n_2  \
# 0  3.604717e+21  1.596788e-07   5.7799  3.601220  1.527047    17.0
# 1  3.663737e+21  1.992386e-07   5.4302  3.718442  1.508194    16.0
# 2  3.661761e+21  2.258195e-07   5.7377  3.743800  1.500487    17.0
# 3  3.587428e+21  1.712427e-07   6.1579  3.697418  1.500424    19.0
# 4  3.508448e+21  1.597114e-07   6.1830  3.664390  1.502069    17.0
#
#         N(13CO)       N(H2)_2   X(13CO)
# 0  5.730193e+15  3.385147e+21  0.000002
# 1  5.383500e+15  3.495336e+21  0.000002
# ...

# %%
b216 = pd.read_csv("B216.dat", sep=r"\s+")
b216.head()
# Out:
#           ra        dec  W(C18O)        AV    AV_sig  AV_n       N(C18O)  \
# 0  65.668856  26.580113  0.24471  1.650970  7.256672  17.0  2.426055e+14
# 1  65.668856  26.590530  0.32500  1.418458  4.178541  18.0  3.222050e+14
# 2  65.668856  26.600947  0.21761  1.268424  1.381616  17.0  2.157386e+14
# 3  65.668856  26.611363  0.27536  1.528151  0.912233  18.0  2.729919e+14
# 4  65.668856  26.621780  0.19976  1.851873  0.490566  21.0  1.980421e+14
#
#           N(H2)       X(C18O)  W(13CO)      AV_2  AV_sig_2  AV_n_2  \
# 0  1.551911e+21  1.563269e-07   1.9389  1.651045  1.499334    17.0
# 1  1.333351e+21  2.416506e-07   2.1436  1.512013  1.483156    18.0
# 2  1.192318e+21  1.809404e-07   2.5416  1.376329  1.491786    18.0
# 3  1.436462e+21  1.900447e-07   3.3862  1.595153  1.503353    19.0
# 4  1.740761e+21  1.137675e-07   3.6738  1.851896  1.514292    21.0
#
#         N(13CO)       N(H2)_2   X(13CO)
# 0  1.922225e+15  1.551982e+21  0.000001
# 1  2.125165e+15  1.421292e+21  0.000001
# ...

# %%
plt.figure(figsize=(9, 6))
sc = plt.scatter(b211["ra"], b211["dec"], c=b211["N(H2)"], cmap='plasma', s=50, alpha=0.7)

plt.colorbar(sc, label="Extiction Value")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("Extinction of N(C18O) in B211")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(9, 6))
sc = plt.scatter(b216["ra"], b216["dec"], c=b216["AV"], cmap='plasma', s=50, alpha=0.7)

plt.colorbar(sc, label="Extiction Value")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("Extinction of C18O in B216")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(9, 6))
sc = plt.scatter(b7["ra"], b7["dec"], c=b7["AV"], cmap='plasma', s=50, alpha=0.7)

plt.colorbar(sc, label="Extiction Value")
plt.xlabel("Rektaszension (RA)")
plt.ylabel("Deklination (Dec)")
plt.title("Extinction of C18O in B7")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(9, 6))
sc = plt.scatter(b213["ra"], b213["dec"], c=b213["N(C18O)"], cmap='plasma', s=50, alpha=0.7)

plt.colorbar(sc, label="N(C18O) Distribution")
plt.xlabel("RA")
plt.ylabel("Dec")
plt.title("B213 N(C18O) Distribution")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(b211['N(C18O)'], bins=45, color='skyblue', edgecolor='black', alpha=0.7)

# Step 3: Customize the plot
plt.title('Histogram of C18O Density Distribution')
plt.xlabel('N(C18O)')
density=False
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(b213['N(C18O)'], bins=45, color='skyblue', edgecolor='black', alpha=0.7)

# Step 3: Customize the plot
plt.title('Histogram of B213 C18O Density Distribution')
plt.xlabel('N(C18O)')
density=False
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.hist(b211['AV'], bins=50, alpha=0.35, label='Av of B211', color='blue')
plt.hist(b7['AV'], bins=50, alpha=0.35, label='Av of B7', color='brown')
plt.hist(b213['AV'], bins=50, alpha=0.35, label='Av of B213', color='green')
plt.hist(b216['AV'], bins=50, alpha=0.35, label='Av of B216', color='black')

plt.xlabel('AV')
plt.ylabel('Häufigkeit')
plt.title('AV Distribution')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(b211['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B211', color='blue')
plt.hist(b7['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B7', color='brown')
plt.hist(b213['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B213', color='green')
plt.hist(b216['N(H2)'], bins=50, alpha=0.35, label='H2 Distribution of B216', color='black')

plt.xlabel('H2')
plt.ylabel('Frequency')
plt.title('H2 Density Distribution measured by C18O')
plt.legend()

plt.show()

# %%
print(b7['AV'].mean())
print(b211['AV'].mean())
print(b213['AV'].mean())
print(b216['AV'].mean())
# Out:
# 6.522904264139559
# 3.853116399807995
# 3.9131061575066846
# 3.6284525249986888

# %%
print(b211['AV'].min())
# Out:
# -0.188426214376

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(b211['N(H2)_2'], bins=50, alpha=0.35, label='H2 Distribution of B211', color='blue')
plt.hist(b7['N(H2)_2'], bins=50, alpha=0.35, label='H2 Distribution of B7', color='brown')
plt.hist(b213['N(H2)_2'], bins=50, alpha=0.35, label='H2 Distribution of B213', color='green')
plt.hist(b216['N(H2)_2'], bins=50, alpha=0.35, label='H2 Distribution of B216', color='black')

plt.xlabel('H2')
plt.ylabel('Frequency')
plt.title('H2 Density Distribution measured by 13CO')
plt.legend()

plt.show()
